# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
from IPython.display import Image, Video

# %%
Image('../plots_and_anims/bdm_cdm1024_r1/accretion_rate/snap_200_1*Tdyn(64).png')

# %%
Image('../plots_and_anims/bdm_cdm1024_r1/accretion_rate/snap_200_2*Tdyn(65).png')

# %%
Video('../plots_and_anims/bdm_cdm1024_r1/accretion_rate/video_2*Tdyn(65).mp4')
# Out:
# <video src="../plots_and_anims/bdm_cdm1024_r1/accretion_rate/video_2*Tdyn(65).mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
ls -alh ../plots_and_anims/bdm_cdm1024_r1/accretion_rate/
# Out:
# total 254M
# drwxr-xr-x 3 cprem beginner 116K Nov 29 18:54 ./
# drwxr-xr-x 7 cprem beginner 4.0K Nov 16 08:51 ../
# drwxr-xr-x 2 cprem beginner 4.0K Nov 22 23:33 .ipynb_checkpoints/
# -rw-r--r-- 1 cprem beginner 171K Nov 17 12:28 snap_100.png
# -rw-r--r-- 1 cprem beginner  72M Nov 17 12:27 snap_100.svg
# -rw-r--r-- 1 cprem beginner  62K Nov 29 18:54 snap_200_100Myr(63).png
# -rw-r--r-- 1 cprem beginner 3.7M Nov 29 18:54 snap_200_100Myr(63).svg
# -rw-r--r-- 1 cprem beginner  57K Nov 29 18:54 snap_200_1*Tdyn(64).png
# -rw-r--r-- 1 cprem beginner 3.7M Nov 29 18:54 snap_200_1*Tdyn(64).svg
# -rw-r--r-- 1 cprem beginner  53K Nov 28 15:56 snap_200_1tdyn.png
# -rw-r--r-- 1 cprem beginner  56K Nov 29 18:54 snap_200_2*Tdyn(65).png
# -rw-r--r-- 1 cprem beginner 3.7M Nov 29 18:54 snap_200_2*Tdyn(65).svg
# -rw-r--r-- 1 cprem beginner  52K Nov 28 13:59 snap_200_2tdyn.png
# -rw-r--r-- 1 cprem beginner  51K Nov 29 18:54 snap_200_Inst(62).png
# ...
