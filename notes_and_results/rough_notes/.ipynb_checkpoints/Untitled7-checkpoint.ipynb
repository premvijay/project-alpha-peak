# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
plt.style.use('dark_background')

# %%
from gadget_tools import Snapshot, read_positions_all_files

# %%
# snap = Snapshot('/scratch/cprem/sims/my-bdm_cdm256_p18/r1/ics_gadget.dat')
snap = Snapshot('/scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_017/snapshot_017.0.hdf5')

# %%
vars(snap)
# Out:
# {'h5py': <module 'h5py' from '/mnt/home/student/cprem/anaconda3/envs/conforg/lib/python3.9/site-packages/h5py/__init__.py'>,
#  'filename': '/scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_017/snapshot_017.0.hdf5',
#  'filetype': 'gadget_hdf5',
#  'N_prtcl_thisfile': array([       0, 30482009,        0,        0,        0,        0],
#        dtype=uint32),
#  'mass_table': array([0.        , 0.50672711, 0.        , 0.        , 0.        ,
#         0.        ]),
#  'scale_factor': 0.8659643233600648,
#  'redshift': 0.15478198468945892,
#  'N_prtcl_total': array([        0, 134217728,         0,         0,         0,         0],
#        dtype=uint64),
#  'num_files': 4,
#  'box_size': 200.0,
#  'Omega_m_0': 0.3063375,
#  'Omega_Lam_0': 0.6936625,
#  'Hubble_param': 0.6781,
#  'num_part_types': 6.0,
#  'params': <Attributes of HDF5 object at 47826054946544>}

# %%
0.063*8
# Out:
# 0.504

# %%
2**27
# Out:
# 134217728

# %%
# np.vstack([np.zeros((3,2)),])

# %%
# posd = read_positions_all_files('/scratch/cprem/sims/my-bdm_cdm512_p18/r1/ics_gadget.dat')

# %%
posd = read_positions_all_files('/scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_018/snapshot_018')
# Out:
# /scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_018/snapshot_018.0.hdf5
# Instantiated a snapshot object, use 'from_binary' method to read from binary.
# /scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_018/snapshot_018.1.hdf5
# Instantiated a snapshot object, use 'from_binary' method to read from binary.
# /scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_018/snapshot_018.2.hdf5
# Instantiated a snapshot object, use 'from_binary' method to read from binary.
# /scratch/cprem/sims/my-bdm_cdm512_p18/r1/snapdir_018/snapshot_018.3.hdf5
# Instantiated a snapshot object, use 'from_binary' method to read from binary.

# %%
# from pm_tools import assign_density

# %%
from pm_tools import assign_density, project_to_slice

# %%
dens = assign_density(posd, snap.box_size)+1

# %%
# dens+1

# %%
# logdens = np.log10(dens+1e-2)

# %%
fig, ax = plt.subplots(1, dpi=150)
im = ax.imshow(dens[250],cmap='Spectral_r',norm = LogNorm(vmin=1e-1, vmax=2e2))
cb = plt.colorbar(im, ax=ax)

# %%
input_power_spec = pd.read_csv('/scratch/cprem/sims/my-bdm_cdm512_p18/input_powerspec.txt', sep='\s+', comment='#', usecols=[0,1], names=['k','pk'])

# %%
power_spec_folding = pd.read_csv('/scratch/cprem/sims/my-bdm_cdm512_p18/r1/powerspecs/powerspec_018.txt', sep='\s+', usecols=[0,1], names=['k', 'Delk'], skiprows=5)

# %%
# power_spec['pk'] = power_spec['Delk']*power_spec['k']**-3*2*np.pi**2

# %%
power_spec_folding
# Out:
#                  k          Delk
# 0     3.141590e-02  4.899830e-02
# 1     4.442880e-02  5.733350e-02
# 2     5.441400e-02  8.580940e-02
# 3     6.283190e-02  1.615740e-01
# 4     7.024810e-02  1.082110e-01
# ...            ...           ...
# 4516  4.099600e+03  2.861540e+08
# 4517  4.111690e+03  2.900760e+08
# 4518  6.801180e+07           NaN
# 4519  1.342180e+08           NaN
# 4520  1.342180e+08           NaN
#
# [4521 rows x 2 columns]

# %%
input_power_spec
# Out:
#                 k            pk
# 0    2.098800e-07  7.367570e-07
# 1    2.243270e-07  7.857810e-07
# 2    2.397690e-07  8.380660e-07
# 3    2.562740e-07  8.938310e-07
# 4    2.739140e-07  9.533060e-07
# ..            ...           ...
# 295  7.090460e+01  7.599060e-10
# 296  7.578540e+01  6.322660e-10
# 297  8.100210e+01  5.258260e-10
# 298  8.657790e+01  4.370920e-10
# 299  9.253750e+01  3.631420e-10
#
# [300 rows x 2 columns]

# %%
# power_spec['pk']*power_spec['k']**-3*2*np.pi**2

# %%
power_spec_folding.sort_values('k', inplace=True)

# %%
power_spec_folding = power_spec_folding[power_spec_folding['k'].between(1e-3,1e2)]

# %%
power_spec_folding['k'].between(1e-3,1e1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2622    False
# 3266    False
# 2623    False
# 3267    False
# 2624    False
# Name: k, Length: 2754, dtype: bool

# %%
power_spec_folding_grouped1 = power_spec_folding.groupby(pd.cut(power_spec_folding['k'], bins=100)).mean()
power_spec_folding_grouped1['pk'] = power_spec_folding_grouped1['Delk']*power_spec_folding_grouped1['k']**-3*2*np.pi**2

# %%
power_spec_existing = pd.read_csv('/scratch/aseem/sims/bdm_cdm1024/r1/Pk_200.txt', comment='#', sep='\t',names=['k','pk','ph','pcross'])

# %%
# power_spec_grouped1.plot('k', 'pk', marker='o', markersize=1)
plt.figure(dpi=150)
plt.plot(power_spec_folding_grouped1['k'], power_spec_folding_grouped1['pk'])
plt.plot(power_spec_existing['k'], power_spec_existing['pk'])
# power_spec_existing.groupby('k').mean().reset_index().plot('k','pk', loglog=True, ax=ax2, color=lighter(color), linestyle='dashed', label='', legend=False)
plt.xscale('log')
plt.yscale('log')
# plt.xlim(right=1e2)
# plt.ylim(bottom=1e-5)

# %%
1/13
# Out:
# 0.07692307692307693

# %%
(1-1/13)/200
# Out:
# 0.004615384615384616

# %%
import os

# %%
# Out:
# True

# %%
(10)**(1/10)
# Out:
# 1.2589254117941673

# %%
0.07692307692307693*1.012907336538952**200
# Out:
# 0.9999999999999842

# %%
z_list = []

# %%
z_list = []
for i in range(0,66):
    snap = Snapshot(f'/scratch/cprem/sims/my-bdm_cdm256_p18/r2/snapshot_{i:03d}')
    z_list.append(snap.redshift)

# %%
z = np.array(z_list)

# %%
a = 1/(1+z)

# %%
plt.scatter(a, a*0)

# %%
plt.plot(a)

# %%
a[1:]/a[:-1]
# Out:
# array([1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.0554496 ,
#        1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        1.04599895, 1.04599895, 1.0554496 , 1.04599895, 1.04599895,
#        1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        1.0554496 , 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.0554496 ,
#        1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        1.04599895, 1.04599895, 1.0554496 , 1.04599895, 1.04599895,
#        1.04599895, 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        1.0554496 , 1.04599895, 1.04599895, 1.04599895, 1.04599895,
#        0.52329911, 1.0554496 , 1.03663293, 1.0554496 , 1.03663293,
#        1.0554496 , 1.03663293, 1.0554496 , 1.0554496 , 1.03663293,
#        1.0554496 , 1.03663293, 1.0554496 , 1.03663293, 1.0554496 ])

# %%
1/10
# Out:
# 0.1

# %%
a
# Out:
# array([0.1       , 0.1045999 , 0.10941138, 0.11444419, 0.1197085 ,
#        0.12634629, 0.13215809, 0.13823722, 0.14459599, 0.15124725,
#        0.15820447, 0.16548171, 0.1730937 , 0.18269167, 0.1910953 ,
#        0.19988548, 0.20908   , 0.21869747, 0.22875732, 0.23927992,
#        0.25028654, 0.26416483, 0.27631614, 0.28902639, 0.3023213 ,
#        0.31622777, 0.33077391, 0.34598917, 0.36190431, 0.37855152,
#        0.39954206, 0.41792057, 0.43714448, 0.45725267, 0.47828581,
#        0.50028646, 0.52329911, 0.54737033, 0.57772179, 0.60429639,
#        0.63209339, 0.66116903, 0.69158211, 0.72339416, 0.75666954,
#        0.79147554, 0.83536255, 0.87378835, 0.9139817 , 0.9560239 ,
#        1.        , 0.52329911, 0.55231584, 0.57254879, 0.60429639,
#        0.62643354, 0.66116903, 0.68538958, 0.72339416, 0.76350608,
#        0.79147554, 0.83536255, 0.86596432, 0.9139817 , 0.94746353,
#        1.        ])

# %%
1.07460783**32
# Out:
# 10.000000499883193

# %%
1.33**.5
# Out:
# 1.1532562594670797

# %%
1.15478198**21
# Out:
# 20.535248513346513

# %%
1/20
# Out:
# 0.05

# %%
np.log(1.15478198)
# Out:
# 0.14391156425122445

# %%
np.log(1.07460783)
# Out:
# 0.07195578571819887

# %%
1.04712854805**50
# Out:
# 9.999999999570527
