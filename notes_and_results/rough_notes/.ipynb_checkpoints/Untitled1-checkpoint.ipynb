# %%
import matplotlib.pyplot as plt
import numpy as np
# import tables

# %%
plt.imshow(np.random.rand(10,30))

# %%
imar = np.zeros((1024,512))
imar[128:256,128:256] = 10

# %%
fig1, ax1 = plt.subplots(figsize=(12,7.5))
im1 = ax1.imshow(imar.T, origin='lower', extent=[-20,20,-10,10], cmap = plt.cm.nipy_spectral)
cb1 = fig1.colorbar(im1, ax=ax1)

# %%
plt.matshow(imar.T, origin='lower', extent=[-20,20,-10,10])

# %%
type(round(4.5))
# Out:
# int

# %%
tables.
