# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
def Omega(z, Om0):
    E = Om0 * (1+z)**3 + (1-Om0)
    return Om0 * (1+z)**3 / E

# %%
def Del_vir(Om):
    x = Om - 1
    return (18*np.pi**2 + 82*x - 39*x**2)/Om

# %%
z = np.logspace(-3, 2)
plt.plot(z, Del_vir(Omega(z, 0.3)))
plt.plot(z, Del_vir(Omega(z, 1)))
plt.xscale('log')

# %%
Om = np.linspace(0.1,1,50)

# %%
plt.plot(Om, Del_vir(Om))
plt.plot(Om, Del_vir(Om/Om))
plt.yscale('log')

# %%
from astropy.cosmology import WMAP9 as cosmo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-307cfa6a5821> in <module>
# ----> 1 from astropy.cosmology import WMAP9 as cosmo
#
# ModuleNotFoundError: No module named 'astropy'
